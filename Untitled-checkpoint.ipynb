# %%
pip install pandas numpy matplotlib seaborn scikit-learn statsmodels plotly
# Out:
# Requirement already satisfied: pandas in c:\users\yogeshwari b m\anaconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in c:\users\yogeshwari b m\anaconda3\lib\site-packages (2.3.5)
# Requirement already satisfied: matplotlib in c:\users\yogeshwari b m\anaconda3\lib\site-packages (3.10.6)
# Requirement already satisfied: seaborn in c:\users\yogeshwari b m\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in c:\users\yogeshwari b m\anaconda3\lib\site-packages (1.7.2)
# Requirement already satisfied: statsmodels in c:\users\yogeshwari b m\anaconda3\lib\site-packages (0.14.5)
# Requirement already satisfied: plotly in c:\users\yogeshwari b m\anaconda3\lib\site-packages (6.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\yogeshwari b m\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\yogeshwari b m\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\yogeshwari b m\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\yogeshwari b m\anaconda3\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\yogeshwari b m\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\yogeshwari b m\anaconda3\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\yogeshwari b m\anaconda3\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\yogeshwari b m\anaconda3\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\yogeshwari b m\anaconda3\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\yogeshwari b m\anaconda3\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\yogeshwari b m\anaconda3\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\yogeshwari b m\anaconda3\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\yogeshwari b m\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\yogeshwari b m\anaconda3\lib\site-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\yogeshwari b m\anaconda3\lib\site-packages (from plotly) (2.7.0)
# Requirement already satisfied: six>=1.5 in c:\users\yogeshwari b m\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("sales_data.csv", encoding="latin1")
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 3       6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 4      11  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
#
#      Customer Name   Segment        Country             City  ... Postal Code  \
# 0      Claire Gute  Consumer  United States        Henderson  ...       42420
# 1      Claire Gute  Consumer  United States        Henderson  ...       42420
# 2   Sean O'Donnell  Consumer  United States  Fort Lauderdale  ...       33311
# 3  Brosina Hoffman  Consumer  United States      Los Angeles  ...       90032
# 4  Brosina Hoffman  Consumer  United States      Los Angeles  ...       90032
#
#    Region       Product ID   Category Sub-Category  \
# 0   South  FUR-BO-10001798  Furniture    Bookcases
# 1   South  FUR-CH-10000454  Furniture       Chairs
# 2   South  FUR-TA-10000577  Furniture       Tables
# 3    West  FUR-FU-10001487  Furniture  Furnishings
# 4    West  FUR-TA-10001539  Furniture       Tables
#
#                                         Product Name      Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase   261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...   731.9400         3
# 2      Bretford CR4500 Series Slim Rectangular Table   957.5775         5
# 3  Eldon Expressions Wood and Plastic Desk Access...    48.8600         7
# 4           Chromcraft Rectangular Conference Tables  1706.1840         9
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.45 -383.0310
# 3      0.00   14.1694
# 4      0.20   85.3092
#
# [5 rows x 21 columns]

# %%
df = pd.read_csv("sales_data.csv", encoding="latin1")
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 3       6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 4      11  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
#
#      Customer Name   Segment        Country             City  ... Postal Code  \
# 0      Claire Gute  Consumer  United States        Henderson  ...       42420
# 1      Claire Gute  Consumer  United States        Henderson  ...       42420
# 2   Sean O'Donnell  Consumer  United States  Fort Lauderdale  ...       33311
# 3  Brosina Hoffman  Consumer  United States      Los Angeles  ...       90032
# 4  Brosina Hoffman  Consumer  United States      Los Angeles  ...       90032
#
#    Region       Product ID   Category Sub-Category  \
# 0   South  FUR-BO-10001798  Furniture    Bookcases
# 1   South  FUR-CH-10000454  Furniture       Chairs
# 2   South  FUR-TA-10000577  Furniture       Tables
# 3    West  FUR-FU-10001487  Furniture  Furnishings
# 4    West  FUR-TA-10001539  Furniture       Tables
#
#                                         Product Name      Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase   261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...   731.9400         3
# 2      Bretford CR4500 Series Slim Rectangular Table   957.5775         5
# 3  Eldon Expressions Wood and Plastic Desk Access...    48.8600         7
# 4           Chromcraft Rectangular Conference Tables  1706.1840         9
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.45 -383.0310
# 3      0.00   14.1694
# 4      0.20   85.3092
#
# [5 rows x 21 columns]

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2121 entries, 0 to 2120
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         2121 non-null   int64
#  1   Order ID       2121 non-null   object
#  2   Order Date     2121 non-null   object
#  3   Ship Date      2121 non-null   object
#  4   Ship Mode      2121 non-null   object
#  5   Customer ID    2121 non-null   object
#  6   Customer Name  2121 non-null   object
#  7   Segment        2121 non-null   object
#  8   Country        2121 non-null   object
#  9   City           2121 non-null   object
#  10  State          2121 non-null   object
#  11  Postal Code    2121 non-null   int64
#  12  Region         2121 non-null   object
#  13  Product ID     2121 non-null   object
#  14  Category       2121 non-null   object
#  15  Sub-Category   2121 non-null   object
#  16  Product Name   2121 non-null   object
#  17  Sales          2121 non-null   float64
#  18  Quantity       2121 non-null   int64
#  19  Discount       2121 non-null   float64
#  20  Profit         2121 non-null   float64
# dtypes: float64(3), int64(3), object(15)
# memory usage: 348.1+ KB
#             Row ID   Postal Code        Sales     Quantity     Discount  \
# count  2121.000000   2121.000000  2121.000000  2121.000000  2121.000000
# mean   5041.643564  55726.556341   349.834887     3.785007     0.173923
# std    2885.740258  32261.888225   503.179145     2.251620     0.181547
# min       1.000000   1040.000000     1.892000     1.000000     0.000000
# 25%    2568.000000  22801.000000    47.040000     2.000000     0.000000
# 50%    5145.000000  60505.000000   182.220000     3.000000     0.200000
# 75%    7534.000000  90032.000000   435.168000     5.000000     0.300000
# max    9991.000000  99301.000000  4416.174000    14.000000     0.700000
#
#             Profit
# count  2121.000000
# mean      8.699327
# std     136.049246
# min   -1862.312400
# 25%     -12.849000
# 50%       7.774800
# 75%      33.726600
# max    1013.127000

# %%
df.isnull().sum()
df.fillna(method='ffill', inplace=True)
# Out:
# C:\Users\YOGESHWARI B M\AppData\Local\Temp\ipykernel_11532\2903114193.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)

# %%
df.columns = df.columns.str.strip()
print(df.columns)
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df['Order Date']
# Out:
# 0        11/8/2016
# 1        11/8/2016
# 2       10/11/2015
# 3         6/9/2014
# 4         6/9/2014
#            ...
# 2116     3/19/2015
# 2117     12/5/2016
# 2118      9/6/2015
# 2119     1/21/2014
# 2120     2/26/2017
# Name: Order Date, Length: 2121, dtype: object

# %%
df.drop_duplicates(inplace=True)

# %%
df['Sales'] = df['Sales'].astype(float)

# %%
sales_over_time = df.groupby('Order Date')['Sales'].sum()

# %%
plt.figure(figsize=(10,5))
plt.plot(sales_over_time)
plt.title("Sales Trend Over Time")
plt.xlabel("Order Date")
plt.ylabel("Sales")
plt.show()

# %%
sns.barplot(x='Category', y='Sales', data=df)
plt.xticks(rotation=45)
plt.show()

# %%
print(df.columns)
# Out:
# Index(['row id', 'order id', 'order date', 'ship date', 'ship mode',
#        'customer id', 'customer name', 'segment', 'country', 'city', 'state',
#        'postal code', 'region', 'product id', 'category', 'sub-category',
#        'product name', 'sales', 'quantity', 'discount', 'profit'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")
print(df.columns)
# Out:
# Index(['row_id', 'order_id', 'order_date', 'ship_date', 'ship_mode',
#        'customer_id', 'customer_name', 'segment', 'country', 'city', 'state',
#        'postal_code', 'region', 'product_id', 'category', 'sub-category',
#        'product_name', 'sales', 'quantity', 'discount', 'profit'],
#       dtype='object')

# %%
df.groupby('product_name')['sales'].sum().sort_values(ascending=False).head(10)
# Out:
# product_name
# HON 5400 Series Task Chairs for Big and Tall                     21870.5760
# Riverside Palais Royal Lawyers Bookcase, Royale Cherry Finish    15610.9656
# Bretford Rectangular Conference Table Tops                       12995.2915
# Global Troy Executive Leather Low-Back Tilter                    12975.3820
# SAFCO Arco Folding Chair                                         11572.7800
# DMI Eclipse Executive Suite Bookcases                            11046.6090
# Hon Deluxe Fabric Upholstered Stacking Chairs, Rounded Back      10637.5280
# Chromcraft Bull-Nose Wood Oval Conference Tables & Bases          9917.6400
# Bush Advantage Collection Racetrack Conference Table              9544.7250
# GuestStacker Chair with Chrome Finish Legs                        9070.9440
# Name: sales, dtype: float64

# %%
print(df.columns.tolist())
# Out:
# ['row_id', 'order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_id', 'customer_name', 'segment', 'country', 'city', 'state', 'postal_code', 'region', 'product_id', 'category', 'sub-category', 'product_name', 'sales', 'quantity', 'discount', 'profit']

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')
print(df.columns)
# Out:
# Index(['row_id', 'order_id', 'order_date', 'ship_date', 'ship_mode',
#        'customer_id', 'customer_name', 'segment', 'country', 'city', 'state',
#        'postal_code', 'region', 'product_id', 'category', 'sub-category',
#        'product_name', 'sales', 'quantity', 'discount', 'profit'],
#       dtype='object')

# %%
df['order_date'] = pd.to_datetime(df['order_date'])

# %%
df['year'] = df['order_date'].dt.year
df['month'] = df['order_date'].dt.month
df['day'] = df['order_date'].dt.day

# %%
print(df[['order_date','year','month']].head())

monthly_sales = (
    df.groupby(['year','month'])['sales']
      .sum()
      .reset_index()
)

monthly_sales.head()
# Out:
#   order_date  year  month
# 0 2016-11-08  2016     11
# 1 2016-11-08  2016     11
# 2 2015-10-11  2015     10
# 3 2014-06-09  2014      6
# 4 2014-06-09  2014      6
#    year  month      sales
# 0  2014      1   6242.525
# 1  2014      2   1839.658
# 2  2014      3  14573.956
# 3  2014      4   7944.837
# 4  2014      5   6912.787

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
ts = df.groupby('order_date')['sales'].sum()

# %%
df['order_date'] = pd.to_datetime(df['order_date'])

# %%
ts = ts.sort_index()
ts.head()
# Out:
# order_date
# 2014-01-06    2573.820
# 2014-01-07      76.728
# 2014-01-10      51.940
# 2014-01-11       9.940
# 2014-01-13     879.939
# Name: sales, dtype: float64

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

# %%
ts.plot(figsize=(10,5), title="Sales Over Time")
# Out:
# <Axes: title={'center': 'Sales Over Time'}, xlabel='order_date'>

# %%
model = ARIMA(ts, order=(5,1,0))
model_fit = model.fit()
# Out:
# C:\Users\YOGESHWARI B M\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\YOGESHWARI B M\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\YOGESHWARI B M\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
forecast = model_fit.forecast(steps=30)
# Out:
# C:\Users\YOGESHWARI B M\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\YOGESHWARI B M\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
plt.figure(figsize=(10,5))
plt.plot(ts, label='Actual')
plt.plot(forecast, label='Forecast')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error

# %%
mae = mean_absolute_error(ts[-30:], forecast[:30])
print("MAE:", mae)
# Out:
# MAE: 1087.229690581211
